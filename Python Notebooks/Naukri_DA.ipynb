# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Import all the libraries")
# Out:
# Import all the libraries

# %%
DATA_DIR = r"C:\WORK\Data Analysis Projects\Job Market Data Analysis Project (Naukari.com)\Datasets\naukri_com-job_sample.csv"

# %%
df=pd.read_csv(DATA_DIR)

# %%
df.head()
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
#
# ...

# %%
df.shape
# Out:
# (22000, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              21996 non-null  str
#  1   education            20004 non-null  str
#  2   experience           21996 non-null  str
#  3   industry             21995 non-null  str
#  4   jobdescription       21996 non-null  str
#  5   jobid                22000 non-null  int64
#  6   joblocation_address  21499 non-null  str
#  7   jobtitle             22000 non-null  str
#  8   numberofpositions    4464 non-null   float64
#  9   payrate              21903 non-null  str
#  10  postdate             21977 non-null  str
#  11  site_name            3987 non-null   str
#  12  skills               21472 non-null  str
#  13  uniq_id              22000 non-null  str
# dtypes: float64(1), int64(1), str(12)
# memory usage: 2.3 MB

# %%
df.isnull().sum()
# Out:
# company                    4
# education               1996
# experience                 4
# industry                   5
# jobdescription             4
# jobid                      0
# joblocation_address      501
# jobtitle                   0
# numberofpositions      17536
# payrate                   97
# postdate                  23
# site_name              18013
# skills                   528
# uniq_id                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
missing_values = df.isnull().sum()

missing_values
# Out:
# company                    4
# education               1996
# experience                 4
# industry                   5
# jobdescription             4
# jobid                      0
# joblocation_address      501
# jobtitle                   0
# numberofpositions      17536
# payrate                   97
# postdate                  23
# site_name              18013
# skills                   528
# uniq_id                    0
# dtype: int64

# %%
percentage_missing = missing_values*100/len(df)
percentage_missing
# Out:
# company                 0.018182
# education               9.072727
# experience              0.018182
# industry                0.022727
# jobdescription          0.018182
# jobid                   0.000000
# joblocation_address     2.277273
# jobtitle                0.000000
# numberofpositions      79.709091
# payrate                 0.440909
# postdate                0.104545
# site_name              81.877273
# skills                  2.400000
# uniq_id                 0.000000
# dtype: float64

# %%
missing_values_df = pd.DataFrame({"Count_Missing":missing_values,
                                  "Percentage_Missing":percentage_missing})

# %%
missing_values_df
# Out:
#                      Count_Missing  Percentage_Missing
# company                          4            0.018182
# education                     1996            9.072727
# experience                       4            0.018182
# industry                         5            0.022727
# jobdescription                   4            0.018182
# jobid                            0            0.000000
# joblocation_address            501            2.277273
# jobtitle                         0            0.000000
# numberofpositions            17536           79.709091
# payrate                         97            0.440909
# postdate                        23            0.104545
# site_name                    18013           81.877273
# skills                         528            2.400000
# uniq_id                          0            0.000000

# %%
df.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id'],
#       dtype='str')

# %%
for col in df.columns:
    print("{} has {} values".format(col,df[col].nunique()))
# Out:
# company has 8469 values
# education has 2355 values
# experience has 147 values
# industry has 63 values
# jobdescription has 21063 values
# jobid has 21910 values
# joblocation_address has 2329 values
# jobtitle has 17564 values
# numberofpositions has 84 values
# payrate has 1848 values
# postdate has 4203 values
# site_name has 1 values
# skills has 45 values
# uniq_id has 22000 values

# %%
unique = []

for col in df.columns:
    unique.append([col,df[col].nunique(),df[col].unique])

# %%
unique
# Out:
# [['company',
#   8469,
#   <bound method Series.unique of 0                                        MM Media Pvt Ltd
#   1                                      find live infotech
#   2                     Softtech Career Infosystem Pvt. Ltd
#   3                                  Onboard HRServices LLP
#   4              Spire Technologies and Solutions Pvt. Ltd.
#                                  ...
#   21995         Morgan Stanley Advantage Services Pvt. Ltd.
#   21996    Careernet Technologies Pvt Ltd hiring for Client
#   21997                                      Musk - Startup
#   21998                                        Confidential
#   21999                     Cambio Consulting India Pvt Ltd
#   Name: company, Length: 22000, dtype: str>],
#  ['education',
#   2355,
#   <bound method Series.unique of 0        UG: B.Tech/B.E. - Any Specialization PG:Any Po...
#   1        UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...
# ...

# %%
unique_df = [[col,df[col].nunique(),df[col].unique()] for col in df.columns]

# %%
pd.DataFrame(unique_df,columns=["col_name","count","unique"])
# Out:
#                col_name  count  \
# 0               company   8469
# 1             education   2355
# 2            experience    147
# 3              industry     63
# 4        jobdescription  21063
# 5                 jobid  21910
# 6   joblocation_address   2329
# 7              jobtitle  17564
# 8     numberofpositions     84
# 9               payrate   1848
# 10             postdate   4203
# 11            site_name      1
# 12               skills     45
# 13              uniq_id  22000
#
#                                                unique
# 0   [MM Media Pvt Ltd, find live infotech, Softtec...
# 1   [UG: B.Tech/B.E. - Any Specialization PG:Any P...
# 2   [0 - 1 yrs, 0 - 0 yrs, 4 - 8 yrs, 11 - 15 yrs,...
# 3   [Media / Entertainment / Internet, Advertising...
# 4   [Job Description   Send me Jobs like this Qual...
# 5   [210516002263, 210516002391, 101016900534, 810...
# 6   [Chennai, Bengaluru, Mumbai, Bengaluru, Kolkat...
# ...

# %%
df.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id'],
#       dtype='str')

# %%
df["payrate"].head(20)
# Out:
# 0                               1,50,000 - 2,25,000 P.A
# 1                        1,50,000 - 2,50,000 P.A. 20000
# 2                            Not Disclosed by Recruiter
# 3                            Not Disclosed by Recruiter
# 4                            Not Disclosed by Recruiter
# 5                            Not Disclosed by Recruiter
# 6                               3,00,000 - 6,50,000 P.A
# 7                            Not Disclosed by Recruiter
# 8                               1,00,000 - 2,00,000 P.A
# 9                            Not Disclosed by Recruiter
# 10                           Not Disclosed by Recruiter
# 11                           Not Disclosed by Recruiter
# 12                              1,75,000 - 2,50,000 P.A
# 13                           Not Disclosed by Recruiter
# 14                           Not Disclosed by Recruiter
# 15                           Not Disclosed by Recruiter
# 16    1,00,000 - 2,00,000 P.A. incentives for achiev...
# ...

# %%
# Min_Payrate
df["payrate"][0].split("-")[0]
# Out:
# '1,50,000 '

# %%
#Max_Payrate
df["payrate"][0].split("-")[1]
# Out:
# ' 2,25,000 P.A'

# %%
len_pay = []
for pay in df["payrate"]:
    len_pay.append(len(str(pay).split("-")))

# %%
pd.Series(len_pay).value_counts()
# Out:
# 1    17028
# 2     4682
# 4      126
# 3       83
# 5       54
# 6       24
# 7        3
# Name: count, dtype: int64

# %%
payrate_split = df["payrate"].str.split("-",expand=True)

# %%
payrate_split
# Out:
#                                 0                     1    2    3    4    5  \
# 0                       1,50,000           2,25,000 P.A  NaN  NaN  NaN  NaN
# 1                       1,50,000    2,50,000 P.A. 20000  NaN  NaN  NaN  NaN
# 2      Not Disclosed by Recruiter                   NaN  NaN  NaN  NaN  NaN
# 3      Not Disclosed by Recruiter                   NaN  NaN  NaN  NaN  NaN
# 4      Not Disclosed by Recruiter                   NaN  NaN  NaN  NaN  NaN
# ...                           ...                   ...  ...  ...  ...  ...
# 21995  Not Disclosed by Recruiter                   NaN  NaN  NaN  NaN  NaN
# 21996                   8,50,000          14,00,000 P.A  NaN  NaN  NaN  NaN
# 21997  Not Disclosed by Recruiter                   NaN  NaN  NaN  NaN  NaN
# 21998  Not Disclosed by Recruiter                   NaN  NaN  NaN  NaN  NaN
# 21999                  12,00,000          22,00,000 P.A  NaN  NaN  NaN  NaN
#
#          6
# 0      NaN
# 1      NaN
# 2      NaN
# ...

# %%
payrate_split[0][0] #There is some Space present, so we have to strip it out
# Out:
# '1,50,000 '

# %%
payrate_split[0]=payrate_split[0].str.strip()

# %%
payrate_split[0]=payrate_split[0].str.replace(",","")

# %%
payrate_split[0]
# Out:
# 0                            150000
# 1                            150000
# 2        Not Disclosed by Recruiter
# 3        Not Disclosed by Recruiter
# 4        Not Disclosed by Recruiter
#                     ...
# 21995    Not Disclosed by Recruiter
# 21996                        850000
# 21997    Not Disclosed by Recruiter
# 21998    Not Disclosed by Recruiter
# 21999                       1200000
# Name: 0, Length: 22000, dtype: str

# %%
pd.to_numeric(payrate_split[0],errors='coerce')
# Out:
# 0         150000.0
# 1         150000.0
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 21995          NaN
# 21996     850000.0
# 21997          NaN
# 21998          NaN
# 21999    1200000.0
# Name: 0, Length: 22000, dtype: float64

# %%
payrate_split[1]=payrate_split[1].str.strip()

# %%
payrate_split[1]
# Out:
# 0               2,25,000 P.A
# 1        2,50,000 P.A. 20000
# 2                        NaN
# 3                        NaN
# 4                        NaN
#                 ...
# 21995                    NaN
# 21996          14,00,000 P.A
# 21997                    NaN
# 21998                    NaN
# 21999          22,00,000 P.A
# Name: 1, Length: 22000, dtype: str

# %%
payrate_split[0]=payrate_split[0].str.replace(",","")

# %%
payrate_split[1]
# Out:
# 0               2,25,000 P.A
# 1        2,50,000 P.A. 20000
# 2                        NaN
# 3                        NaN
# 4                        NaN
#                 ...
# 21995                    NaN
# 21996          14,00,000 P.A
# 21997                    NaN
# 21998                    NaN
# 21999          22,00,000 P.A
# Name: 1, Length: 22000, dtype: str

# %%
payrate_split[1][0]
# Now we will use regular expression to extract only numeric values from the text # As it also contains P.A
# Out:
# '2,25,000 P.A'

# %%
payrate_split[1]=payrate_split[1].str.replace(",","")

# %%
payrate_split[1]
# Out:
# 0               225000 P.A
# 1        250000 P.A. 20000
# 2                      NaN
# 3                      NaN
# 4                      NaN
#                ...
# 21995                  NaN
# 21996          1400000 P.A
# 21997                  NaN
# 21998                  NaN
# 21999          2200000 P.A
# Name: 1, Length: 22000, dtype: str

# %%
pattern = "\D.*"
payrate_split[1]=payrate_split[1].str.replace(pattern,"",regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\vinay pratap singh\AppData\Local\Temp\ipykernel_21636\75164378.py:1: SyntaxWarning: invalid escape sequence '\D'
#   pattern = "\D.*"

# %%
payrate_split[1]
# Out:
# 0         225000
# 1         250000
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 21995        NaN
# 21996    1400000
# 21997        NaN
# 21998        NaN
# 21999    2200000
# Name: 1, Length: 22000, dtype: str

# %%
payrate_split
# Out:
#                                 0        1    2    3    4    5    6
# 0                          150000   225000  NaN  NaN  NaN  NaN  NaN
# 1                          150000   250000  NaN  NaN  NaN  NaN  NaN
# 2      Not Disclosed by Recruiter      NaN  NaN  NaN  NaN  NaN  NaN
# 3      Not Disclosed by Recruiter      NaN  NaN  NaN  NaN  NaN  NaN
# 4      Not Disclosed by Recruiter      NaN  NaN  NaN  NaN  NaN  NaN
# ...                           ...      ...  ...  ...  ...  ...  ...
# 21995  Not Disclosed by Recruiter      NaN  NaN  NaN  NaN  NaN  NaN
# 21996                      850000  1400000  NaN  NaN  NaN  NaN  NaN
# 21997  Not Disclosed by Recruiter      NaN  NaN  NaN  NaN  NaN  NaN
# 21998  Not Disclosed by Recruiter      NaN  NaN  NaN  NaN  NaN  NaN
# 21999                     1200000  2200000  NaN  NaN  NaN  NaN  NaN
#
# [22000 rows x 7 columns]

# %%
payrate_split.dtypes
# Out:
# 0    str
# 1    str
# 2    str
# 3    str
# 4    str
# 5    str
# 6    str
# dtype: object

# %%
payrate_split[0] = pd.to_numeric(payrate_split[0],errors="coerce")
payrate_split[1] = pd.to_numeric(payrate_split[1],errors="coerce")

# %%
payrate_split.dtypes
# Out:
# 0    float64
# 1    float64
# 2        str
# 3        str
# 4        str
# 5        str
# 6        str
# dtype: object

# %%
df["min_pay"]=payrate_split[0]
df["max_pay"]=payrate_split[1]

# %%
df.head()
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
#
# ...

# %% [markdown]
# #### Clean the experience feature

# %%
df["experience"].head(20)
# Out:
# 0       0 - 1 yrs
# 1       0 - 0 yrs
# 2       4 - 8 yrs
# 3     11 - 15 yrs
# 4       6 - 8 yrs
# 5       2 - 5 yrs
# 6       1 - 3 yrs
# 7       2 - 7 yrs
# 8       1 - 3 yrs
# 9       1 - 5 yrs
# 10      1 - 3 yrs
# 11      4 - 8 yrs
# 12      2 - 4 yrs
# 13      3 - 8 yrs
# 14      1 - 5 yrs
# 15      5 - 7 yrs
# 16      1 - 2 yrs
# 17      2 - 4 yrs
# 18     5 - 10 yrs
# 19      0 - 1 yrs
# Name: experience, dtype: str

# %%
df["experience"].value_counts().head(30)
# Out:
# experience
# 2 - 7 yrs      1712
# 2 - 5 yrs      1231
# 3 - 8 yrs      1192
# 3 - 5 yrs      1181
# 5 - 10 yrs     1084
# 1 - 3 yrs       755
# 2 - 4 yrs       729
# 4 - 9 yrs       715
# 0 - 5 yrs       654
# 3 - 6 yrs       613
# 1 - 6 yrs       591
# 0 - 3 yrs       556
# 10 - 15 yrs     517
# 0 - 1 yrs       509
# 5 - 8 yrs       499
# 1 - 5 yrs       498
# 0 - 2 yrs       481
# 1 - 2 yrs       477
# 6 - 11 yrs      469
# 2 - 3 yrs       454
# 4 - 6 yrs       420
# 4 - 8 yrs       408
# 1 - 4 yrs       401
# 2 - 6 yrs       391
# 5 - 7 yrs       377
# 7 - 12 yrs      328
# 3 - 7 yrs       319
# 8 - 13 yrs      311
# 4 - 7 yrs       296
# 8 - 10 yrs      270
# Name: count, dtype: int64

# %%
exp_split = df["experience"].str.split("-",expand=True)

# %%
exp_split
# Out:
#          0        1    2
# 0       0     1 yrs  NaN
# 1       0     0 yrs  NaN
# 2       4     8 yrs  NaN
# 3      11    15 yrs  NaN
# 4       6     8 yrs  NaN
# ...    ...      ...  ...
# 21995   9    13 yrs  NaN
# 21996   3     5 yrs  NaN
# 21997   2     4 yrs  NaN
# 21998   7    12 yrs  NaN
# 21999   5    10 yrs  NaN
#
# [22000 rows x 3 columns]

# %%
exp_split[0] = exp_split[0].str.strip()

# %%
exp_split[1] = exp_split[1].str.strip()

# %%
exp_split[1] = exp_split[1].str.replace("yrs","")

# %%
exp_split
# Out:
#         0    1    2
# 0       0   1   NaN
# 1       0   0   NaN
# 2       4   8   NaN
# 3      11  15   NaN
# 4       6   8   NaN
# ...    ..  ...  ...
# 21995   9  13   NaN
# 21996   3   5   NaN
# 21997   2   4   NaN
# 21998   7  12   NaN
# 21999   5  10   NaN
#
# [22000 rows x 3 columns]

# %%
exp_split.dtypes
# Out:
# 0    str
# 1    str
# 2    str
# dtype: object

# %%
exp_split[0] = pd.to_numeric(exp_split[0],errors="coerce")
exp_split[1] = pd.to_numeric(exp_split[1],errors="coerce")

# %%
exp_split.dtypes
# Out:
# 0    float64
# 1    float64
# 2        str
# dtype: object

# %%
exp_split
# Out:
#           0     1    2
# 0       0.0   1.0  NaN
# 1       0.0   0.0  NaN
# 2       4.0   8.0  NaN
# 3      11.0  15.0  NaN
# 4       6.0   8.0  NaN
# ...     ...   ...  ...
# 21995   9.0  13.0  NaN
# 21996   3.0   5.0  NaN
# 21997   2.0   4.0  NaN
# 21998   7.0  12.0  NaN
# 21999   5.0  10.0  NaN
#
# [22000 rows x 3 columns]

# %%
df["min_exp"] = exp_split[0]
df["max_exp"] = exp_split[1]

# %%
df.head(20)
# Out:
#                                               company  \
# 0                                    MM Media Pvt Ltd
# 1                                  find live infotech
# 2                 Softtech Career Infosystem Pvt. Ltd
# 3                              Onboard HRServices LLP
# 4          Spire Technologies and Solutions Pvt. Ltd.
# 5                     PFS Web Global Services Pvt Ltd
# 6              Kinesis Management Consultant Pvt. Ltd
# 7   Agile HR consultancy Pvt. Ltd. hiring for Ross...
# 8                   HANSUM INDIA ELECTRONICS PVT.LTD.
# 9                                           Accenture
# 10                                            Premium
# 11        Convate hiring for Retail/e-commerce domain
# 12                                       Sinai Global
# 13            Mathematical Computing Software Company
# 14                                          Accenture
# 15                                   PKS & Associates
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              21996 non-null  str
#  1   education            20004 non-null  str
#  2   experience           21996 non-null  str
#  3   industry             21995 non-null  str
#  4   jobdescription       21996 non-null  str
#  5   jobid                22000 non-null  int64
#  6   joblocation_address  21499 non-null  str
#  7   jobtitle             22000 non-null  str
#  8   numberofpositions    4464 non-null   float64
#  9   payrate              21903 non-null  str
#  10  postdate             21977 non-null  str
#  11  site_name            3987 non-null   str
#  12  skills               21472 non-null  str
#  13  uniq_id              22000 non-null  str
#  14  min_pay              4641 non-null   float64
#  15  max_pay              4940 non-null   float64
# ...

# %%
df["avg_pay"] = (df["min_pay"]+df["max_pay"])/2
df["avg_exp"] = (df["min_exp"]+df["max_exp"])/2

# %%
df.head(20)
# Out:
#                                               company  \
# 0                                    MM Media Pvt Ltd
# 1                                  find live infotech
# 2                 Softtech Career Infosystem Pvt. Ltd
# 3                              Onboard HRServices LLP
# 4          Spire Technologies and Solutions Pvt. Ltd.
# 5                     PFS Web Global Services Pvt Ltd
# 6              Kinesis Management Consultant Pvt. Ltd
# 7   Agile HR consultancy Pvt. Ltd. hiring for Ross...
# 8                   HANSUM INDIA ELECTRONICS PVT.LTD.
# 9                                           Accenture
# 10                                            Premium
# 11        Convate hiring for Retail/e-commerce domain
# 12                                       Sinai Global
# 13            Mathematical Computing Software Company
# 14                                          Accenture
# 15                                   PKS & Associates
# ...

# %%
df.dtypes
# Out:
# company                    str
# education                  str
# experience                 str
# industry                   str
# jobdescription             str
# jobid                    int64
# joblocation_address        str
# jobtitle                   str
# numberofpositions      float64
# payrate                    str
# postdate                   str
# site_name                  str
# skills                     str
# uniq_id                    str
# min_pay                float64
# max_pay                float64
# min_exp                float64
# max_exp                float64
# avg_pay                float64
# avg_exp                float64
# dtype: object

# %% [markdown]
# #### Perform Feature Engineering on Postdate Feature

# %%
df["postdate"]
# Out:
# 0        2016-05-21 19:30:00 +0000
# 1        2016-05-21 19:30:00 +0000
# 2        2016-10-13 16:20:55 +0000
# 3        2016-10-13 16:20:55 +0000
# 4        2016-10-13 16:20:55 +0000
#                    ...
# 21995    2016-11-25 22:47:05 +0000
# 21996    2016-11-24 22:47:05 +0000
# 21997    2016-11-25 22:47:05 +0000
# 21998    2016-11-27 22:47:05 +0000
# 21999    2016-11-25 22:47:05 +0000
# Name: postdate, Length: 22000, dtype: str

# %%
df["postdate"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
pd.to_datetime(df["postdate"],errors="coerce")
# Out:
# 0       2016-05-21 19:30:00+00:00
# 1       2016-05-21 19:30:00+00:00
# 2       2016-10-13 16:20:55+00:00
# 3       2016-10-13 16:20:55+00:00
# 4       2016-10-13 16:20:55+00:00
#                    ...
# 21995   2016-11-25 22:47:05+00:00
# 21996   2016-11-24 22:47:05+00:00
# 21997   2016-11-25 22:47:05+00:00
# 21998   2016-11-27 22:47:05+00:00
# 21999   2016-11-25 22:47:05+00:00
# Name: postdate, Length: 22000, dtype: datetime64[us, UTC]

# %%
df["postdate"]=pd.to_datetime(df["postdate"],errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              21996 non-null  str
#  1   education            20004 non-null  str
#  2   experience           21996 non-null  str
#  3   industry             21995 non-null  str
#  4   jobdescription       21996 non-null  str
#  5   jobid                22000 non-null  int64
#  6   joblocation_address  21499 non-null  str
#  7   jobtitle             22000 non-null  str
#  8   numberofpositions    4464 non-null   float64
#  9   payrate              21903 non-null  str
#  10  postdate             21977 non-null  datetime64[us, UTC]
#  11  site_name            3987 non-null   str
#  12  skills               21472 non-null  str
#  13  uniq_id              22000 non-null  str
#  14  min_pay              4641 non-null   float64
# ...

# %%
df["year"] = df["postdate"].dt.year

# %%
df["month"] = df["postdate"].dt.month

# %%
df["day"] = df["postdate"].dt.day

# %%
df.head()
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              21996 non-null  str
#  1   education            20004 non-null  str
#  2   experience           21996 non-null  str
#  3   industry             21995 non-null  str
#  4   jobdescription       21996 non-null  str
#  5   jobid                22000 non-null  int64
#  6   joblocation_address  21499 non-null  str
#  7   jobtitle             22000 non-null  str
#  8   numberofpositions    4464 non-null   float64
#  9   payrate              21903 non-null  str
#  10  postdate             21977 non-null  datetime64[us, UTC]
#  11  site_name            3987 non-null   str
#  12  skills               21472 non-null  str
#  13  uniq_id              22000 non-null  str
#  14  min_pay              4641 non-null   float64
# ...

# %% [markdown]
# #### Perform Feature Engineering on job_location Feature

# %%
df["joblocation_address"].value_counts().head(20)
# Out:
# joblocation_address
# Bengaluru/Bangalore                                         3775
# Mumbai                                                      2348
# Bengaluru                                                   1453
# Hyderabad / Secunderabad                                    1246
# Chennai                                                     1204
# Hyderabad                                                    936
# Noida                                                        775
# Delhi                                                        763
# Gurgaon                                                      743
# Mumbai , Mumbai                                              514
# Delhi/NCR(National Capital Region)                           383
# Bengaluru/Bangalore , Bengaluru / Bangalore                  360
# Delhi , Delhi                                                324
# Noida , Noida/Greater Noida                                  313
# ...

# %%
data = df.copy()

# %%
pd.Series(data["joblocation_address"].unique())
# Out:
# 0                                                 Chennai
# 1                                               Bengaluru
# 2       Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 3       Delhi NCR, Mumbai, Bengaluru, Kochi, Greater N...
# 4                                Mumbai, Delhi, Bengaluru
#                               ...
# 2325                           Mumbai, Bengaluru, Kolkata
# 2326                  Bengaluru, Pune, Chennai, Delhi NCR
# 2327                Mumbai, Bengaluru, Hyderabad, Kolkata
# 2328    Mumbai, Chennai, Delhi, Bengaluru, Hyderabad, ...
# 2329                                  Bengaluru, Malaysia
# Length: 2330, dtype: str

# %%
#Top 60 cities that has more number of job location
data["joblocation_address"].value_counts().head(60).index
# Out:
# Index(['Bengaluru/Bangalore', 'Mumbai', 'Bengaluru',
#        'Hyderabad / Secunderabad', 'Chennai', 'Hyderabad', 'Noida', 'Delhi',
#        'Gurgaon', 'Mumbai , Mumbai', 'Delhi/NCR(National Capital Region)',
#        'Bengaluru/Bangalore , Bengaluru / Bangalore', 'Delhi , Delhi',
#        'Noida , Noida/Greater Noida', 'Gurgaon , Gurgaon',
#        'Bengaluru/Bangalore , Chennai , Hyderabad / Secunderabad', 'Ghaziabad',
#        'Bengaluru/Bangalore , Hyderabad / Secunderabad',
#        'Bengaluru, Hyderabad', 'Delhi/NCR(National Capital Region) , Gurgaon',
#        'Bengaluru/Bangalore , Chennai',
#        'Bengaluru/Bangalore , Mumbai , Chennai , Pune , Hyderabad / Secunderabad , Delhi/NCR(National Capital Region) , Ahmedabad , Kolkata , Surat',
#        'Bengaluru/Bangalore , karnataka',
#        'Delhi , Delhi/NCR(National Capital Region)',
#        'Chennai , Hyderabad / Secunderabad',
#        'Hyderabad / Secunderabad , Hyderabad/Secunderabad',
# ...

# %%
replacement = pd.read_csv(r"C:\WORK\Data Analysis Projects\Job Market Data Analysis Project (Naukari.com)\Datasets\replacements.csv").set_index("Unnamed: 0")

# %%
replacement
# Out:
#                                                    joblocation_address
# Unnamed: 0
#  Delhi/NCR(National Capital Region)                              Delhi
#  Delhi/NCR(National Capital Region)                              Delhi
# (Bengaluru/Bangalore)                                        Bangalore
# Bangalore                                                    Bangalore
# Bangalore , Bangalore / Bangalore                            Bangalore
# Bangalore Bangalore                                          Bangalore
# Bangalore,Bangalore / Bangalore                              Bangalore
# Bangalore,karnataka                                          Bangalore
# Bengaluru                                                    Bangalore
# Bengaluru/Bangalore                                          Bangalore
# Bengaluru/Bangalore , bangalore                              Bangalore
# DELHI(NATIONAL CAPITAL REGION)                                   Delhi
# ...

# %%
replacement_dict = replacement.to_dict()

# %%
data.replace(replacement_dict,inplace=True,regex=True)
# Out:
#                                                 company  \
# 0                                      MM Media Pvt Ltd
# 1                                    find live infotech
# 2                   Softtech Career Infosystem Pvt. Ltd
# 3                                Onboard HRServices LLP
# 4            Spire Technologies and Solutions Pvt. Ltd.
# ...                                                 ...
# 21995       Morgan Stanley Advantage Services Pvt. Ltd.
# 21996  Careernet Technologies Pvt Ltd hiring for Client
# 21997                                    Musk - Startup
# 21998                                      Confidential
# 21999                   Cambio Consulting India Pvt Ltd
#
#                                                education   experience  \
# 0      UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1      UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2      UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# ...

# %%
data["joblocation_address"].value_counts()
# Out:
# joblocation_address
# Bangalore                                             5228
# Mumbai                                                2887
# Delhi                                                 2741
# Hyderabad                                             2182
# Chennai                                               1204
#                                                       ...
# Mumbai, Bangalore, Kolkata                               1
# Bangalore, Pune, Chennai, Delhi                          1
# Mumbai, Bangalore, Hyderabad, Kolkata                    1
# Mumbai, Chennai, Delhi, Bangalore, Hyderabad, Pune       1
# Bangalore, Malaysia                                      1
# Name: count, Length: 2141, dtype: int64

# %%
# initial we have only 3775 in banglore job location, but now its 5228
df["joblocation_address"].value_counts().head(10)
# Out:
# joblocation_address
# Bengaluru/Bangalore         3775
# Mumbai                      2348
# Bengaluru                   1453
# Hyderabad / Secunderabad    1246
# Chennai                     1204
# Hyderabad                    936
# Noida                        775
# Delhi                        763
# Gurgaon                      743
# Mumbai , Mumbai              514
# Name: count, dtype: int64

# %%
data.head(3)
# Out:
#                                company  \
# 0                     MM Media Pvt Ltd
# 1                   find live infotech
# 2  Softtech Career Infosystem Pvt. Ltd
#
#                                            education experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...  0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...  0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...  4 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
#
#   joblocation_address                                  jobtitle  \
# ...

# %%
data.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id', 'min_pay',
#        'max_pay', 'min_exp', 'max_exp', 'avg_pay', 'avg_exp', 'year', 'month',
#        'day'],
#       dtype='str')

# %%
def drop_feature(column):
    data.drop(column,axis=1,inplace=True)

# %%
drop_feature("payrate")

# %%
drop_feature("experience")
drop_feature("postdate")
drop_feature("uniq_id")

# %%
data.columns
# Out:
# Index(['company', 'education', 'industry', 'jobdescription', 'jobid',
#        'joblocation_address', 'jobtitle', 'numberofpositions', 'site_name',
#        'skills', 'min_pay', 'max_pay', 'min_exp', 'max_exp', 'avg_pay',
#        'avg_exp', 'year', 'month', 'day'],
#       dtype='str')

# %%
data.to_csv(r"../Datasets/Updated_datasets/naukri_data2.csv",index=False)
